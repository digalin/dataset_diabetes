# %%
# Diego Galindo, Francisco Mercado

import pandas as pd 
from sklearn.decomposition import PCA, SparsePCA, IncrementalPCA, FastICA

# %%
df_data = pd.read_csv("../results/3_standardization_final.csv")
df_data
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness       Insulin  \
# 0       0.639947  0.865108      -0.033518   6.655021e-01 -4.634358e-18
# 1      -0.844885 -1.206162      -0.529859  -1.746338e-02 -4.634358e-18
# 2       1.233880  2.015813      -0.695306   3.501613e-17 -4.634358e-18
# 3      -0.844885 -1.074652      -0.529859  -7.004289e-01 -7.243887e-01
# 4      -1.141852  0.503458      -2.680669   6.655021e-01  1.465506e-01
# ..           ...       ...            ...            ...           ...
# 763     1.827813 -0.680125       0.297376   2.145261e+00  2.877840e-01
# 764    -0.547919  0.010298      -0.198965  -2.451185e-01 -4.634358e-18
# 765     0.342981 -0.022579      -0.033518  -7.004289e-01 -5.125386e-01
# 766    -0.844885  0.141808      -1.026200   3.501613e-17 -4.634358e-18
# 767    -0.844885 -0.943143      -0.198965   2.101918e-01 -4.634358e-18
#
#           BMI  DiabetesPedigreeFunction       Age  is_isolated  is_lof  \
# 0    0.166292                  0.468492  1.425995            1       1
# 1   -0.852531                 -0.365061 -0.190672            1       1
# 2   -1.332833                  0.604397 -0.105584            1       1
# 3   -0.634212                 -0.920763 -1.041549            1       1
# 4    1.548980                  5.484909 -0.020496           -1      -1
# ..        ...                       ...       ...          ...     ...
# 763  0.064409                 -0.908682  2.532136           -1      -1
# 764  0.632039                 -0.398282 -0.531023            1       1
# 765 -0.910750                 -0.685193 -0.275760            1       1
# 766 -0.343120                 -0.371101  1.170732            1       1
# 767 -0.299456                 -0.473785 -0.871374            1       1
#
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 11 columns]

# %%
df_data_not_use = df_data[["is_isolated", "is_lof", "Outcome"]]  # Ajusta según el nombre de la columna de salida
df_data_values = df_data.drop(columns=["is_isolated", "is_lof", "Outcome"])  # Las características estandarizadas que se usarán

# %%
pca_instance = PCA()
pca_instance.fit(df_data_values.values)

print(pca_instance)
# Out:
# PCA()

# %%
sparse_pca_instance = SparsePCA()
sparse_pca_instance.fit(df_data_values.values)
sparse_pca_instance
# Out:
# SparsePCA()

# %%
incremetal_PCA = IncrementalPCA()
incremetal_PCA.fit(df_data_values.values)
incremetal_PCA
# Out:
# IncrementalPCA()

# %%
pca_instance.explained_variance_
# Out:
# array([2.30300915, 1.47480727, 1.12964891, 0.92874429, 0.76944503,
#        0.55041715, 0.47102389, 0.38333455])

# %%
pca_instance.explained_variance_ratio_ * 100
# Out:
# array([28.75013054, 18.41108686, 14.10222522, 11.59418731,  9.60553934,
#         6.87125572,  5.88013226,  4.78544276])

# %%
data_transform = pca_instance.transform(df_data_values.values)
data_transform
# Out:
# array([[ 1.50362957,  0.5880889 ,  0.19627683, ...,  0.64420839,
#         -0.47062384,  0.26062621],
#        [-1.43751319, -0.07698799, -0.10115985, ..., -0.60850827,
#         -0.87630486,  0.10117033],
#        [ 0.49223335,  0.8125685 ,  1.65337386, ...,  1.46463067,
#          0.27483596, -1.39222665],
#        ...,
#        [-0.9191384 ,  0.95161087,  0.0501147 , ...,  0.30342132,
#          0.21621281, -0.41996163],
#        [-0.31700403,  0.23101492,  0.50960441, ...,  0.55860975,
#         -1.06869996,  1.08393629],
#        [-1.18028819, -0.68885145, -0.40574496, ..., -0.52763248,
#         -0.38867272, -0.20746557]])
